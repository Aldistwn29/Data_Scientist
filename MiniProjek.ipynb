# %% [markdown]
# <a href="https://colab.research.google.com/github/Aldistwn29/Data_Scientist/blob/main/MiniProjek.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Setelah mengerjakan kasus dari Kroma, aku dapet kasus lagi! Kali ini lebih sederhana tapi enggak bisa kuanggap remeh juga. Jadi, perusahaan retail tempat aku bekerja akan membuka toko offline. Di dalam toko tersebut, mereka berencana untuk melakukan peletakkan produk. Di mana produk yang memiliki asosiasi, harus diletakan berdekatan.
#
# Oleh karena itu, aku ditugaskan untuk menyiapkan data yang dapat dianalisis sebagai pendukung keputusan peletakan produk di toko tersebut. Untuk menyelesaikan tugasku, aku kembali menggunakan teknik Market Basket Analysis menggunakan algoritma Apriori yang sudah aku pelajari.
#
# Aku akan menggunakan parameter min_support=0.04.
#
# So, here we go!

# %%
import pandas as pd
dataset_transaksi = pd.read_csv("https://storage.googleapis.com/dqlab-dataset/transaksi_dqlab_retail.tsv", sep="\t")

# %%
# mengelompokkan pada keranjang yg sama
dataset_transaksi["Flag"] = 1

# %%
dataset_transaksi
# Out:
#       Kode Transaksi              Nama Barang  Flag
# 0                 #1                     Kaos     1
# 1                 #1             Shampo Biasa     1
# 2                 #1      Sepatu Sport merk Z     1
# 3                 #1            Serum Vitamin     1
# 4                 #1  Baju Renang Pria Dewasa     1
# ...              ...                      ...   ...
# 33663          #3450     Flat Shoes Ballerina     1
# 33664          #3450       Sepatu Sandal Anak     1
# 33665          #3450      Sepatu Kulit Casual     1
# 33666          #3450     Celana Jogger Casual     1
# 33667          #3450      Sepatu Sport merk Z     1
#
# [33668 rows x 3 columns]

# %%
dataset_transaksi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33668 entries, 0 to 33667
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Kode Transaksi  33668 non-null  object
#  1   Nama Barang     33668 non-null  object
#  2   Flag            33668 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 789.2+ KB

# %%
# mengelompokan Kode Transaksi dan Nama barang dengan menjumlahkan Flag
basket = dataset_transaksi.groupby(["Kode Transaksi", "Nama Barang"])["Flag"].sum().unstack().reset_index().fillna(0).set_index("Kode Transaksi")
basket.head()
# Out:
# Nama Barang     Atasan Baju Belang  Atasan Kaos Putih  Baju Batik Wanita  \
# Kode Transaksi
# #1                             0.0                0.0                0.0
# #10                            0.0                0.0                1.0
# #100                           0.0                0.0                0.0
# #1000                          0.0                0.0                1.0
# #1001                          0.0                0.0                0.0
#
# Nama Barang     Baju Kaos Anak - Karakter Kartun  \
# Kode Transaksi
# #1                                           0.0
# #10                                          0.0
# #100                                         0.0
# #1000                                        0.0
# #1001                                        0.0
#
# Nama Barang     Baju Kaos Anak - Superheroes  Baju Kaos Olahraga  \
# Kode Transaksi
# #1                                       0.0                 1.0
# #10                                      0.0                 0.0
# #100                                     0.0                 0.0
# #1000                                    0.0                 0.0
# #1001                                    0.0                 0.0
#
# Nama Barang     Baju Kemeja Putih  Baju Renang Anak Perempuan  \
# Kode Transaksi
# #1                            0.0                         0.0
# #10                           1.0                         0.0
# #100                          0.0                         0.0
# #1000                         0.0                         0.0
# #1001                         0.0                         0.0
#
# Nama Barang     Baju Renang Pria Anak-anak  Baju Renang Pria Dewasa  ...  \
# Kode Transaksi                                                       ...
# #1                                     0.0                      1.0  ...
# #10                                    0.0                      0.0  ...
# #100                                   0.0                      0.0  ...
# #1000                                  0.0                      1.0  ...
# #1001                                  0.0                      1.0  ...
#
# Nama Barang     Tas Multifungsi  Tas Pinggang Wanita  Tas Ransel Mini  \
# Kode Transaksi
# #1                          0.0                  0.0              0.0
# #10                         0.0                  0.0              0.0
# #100                        0.0                  0.0              0.0
# #1000                       0.0                  0.0              0.0
# #1001                       0.0                  0.0              0.0
#
# Nama Barang     Tas Sekolah Anak Laki-laki  Tas Sekolah Anak Perempuan  \
# Kode Transaksi
# #1                                     0.0                         0.0
# #10                                    0.0                         0.0
# #100                                   0.0                         0.0
# #1000                                  0.0                         0.0
# #1001                                  1.0                         0.0
#
# Nama Barang     Tas Tangan  Tas Travel  Tas Waist Bag  Wedges Hitam  \
# Kode Transaksi
# #1                     0.0         0.0            0.0           0.0
# #10                    0.0         0.0            0.0           1.0
# #100                   0.0         0.0            0.0           0.0
# #1000                  0.0         0.0            0.0           0.0
# #1001                  0.0         1.0            0.0           1.0
#
# Nama Barang     Woman Ripped Jeans
# Kode Transaksi
# #1                              0.0
# #10                             0.0
# #100                            0.0
# #1000                           0.0
# #1001                           0.0
#
# [5 rows x 69 columns]

# %%
# Membuat function untuk menormalisasikan data
def encode_units(x):
  if x <= 0:
    return 0
  if x > 0:
    return 1

# %%
# Menerapkan fungsi yg telah dibuat untuk menormalisasikan data
basket_encode = basket.applymap(encode_units)
basket_encode
# Out:
# Nama Barang     Atasan Baju Belang  Atasan Kaos Putih  Baju Batik Wanita  \
# Kode Transaksi
# #1                               0                  0                  0
# #10                              0                  0                  1
# #100                             0                  0                  0
# #1000                            0                  0                  1
# #1001                            0                  0                  0
# ...                            ...                ...                ...
# #995                             0                  1                  0
# #996                             0                  0                  0
# #997                             0                  0                  1
# #998                             0                  0                  1
# #999                             0                  0                  1
#
# Nama Barang     Baju Kaos Anak - Karakter Kartun  \
# Kode Transaksi
# #1                                             0
# #10                                            0
# #100                                           0
# #1000                                          0
# #1001                                          0
# ...                                          ...
# #995                                           0
# #996                                           0
# #997                                           0
# #998                                           0
# #999                                           1
#
# Nama Barang     Baju Kaos Anak - Superheroes  Baju Kaos Olahraga  \
# Kode Transaksi
# #1                                         0                   1
# #10                                        0                   0
# #100                                       0                   0
# #1000                                      0                   0
# #1001                                      0                   0
# ...                                      ...                 ...
# #995                                       0                   1
# #996                                       0                   0
# #997                                       1                   0
# #998                                       1                   0
# #999                                       0                   0
#
# Nama Barang     Baju Kemeja Putih  Baju Renang Anak Perempuan  \
# Kode Transaksi
# #1                              0                           0
# #10                             1                           0
# #100                            0                           0
# #1000                           0                           0
# #1001                           0                           0
# ...                           ...                         ...
# #995                            0                           0
# #996                            0                           0
# #997                            1                           0
# #998                            0                           0
# #999                            0                           0
#
# Nama Barang     Baju Renang Pria Anak-anak  Baju Renang Pria Dewasa  ...  \
# Kode Transaksi                                                       ...
# #1                                       0                        1  ...
# #10                                      0                        0  ...
# #100                                     0                        0  ...
# #1000                                    0                        1  ...
# #1001                                    0                        1  ...
# ...                                    ...                      ...  ...
# #995                                     0                        1  ...
# #996                                     0                        1  ...
# #997                                     0                        0  ...
# #998                                     0                        0  ...
# #999                                     0                        0  ...
#
# Nama Barang     Tas Multifungsi  Tas Pinggang Wanita  Tas Ransel Mini  \
# Kode Transaksi
# #1                            0                    0                0
# #10                           0                    0                0
# #100                          0                    0                0
# #1000                         0                    0                0
# #1001                         0                    0                0
# ...                         ...                  ...              ...
# #995                          0                    0                0
# #996                          1                    0                0
# #997                          0                    0                0
# #998                          0                    1                0
# #999                          0                    0                0
#
# Nama Barang     Tas Sekolah Anak Laki-laki  Tas Sekolah Anak Perempuan  \
# Kode Transaksi
# #1                                       0                           0
# #10                                      0                           0
# #100                                     0                           0
# #1000                                    0                           0
# #1001                                    1                           0
# ...                                    ...                         ...
# #995                                     0                           0
# #996                                     1                           0
# #997                                     0                           0
# #998                                     0                           0
# #999                                     0                           0
#
# Nama Barang     Tas Tangan  Tas Travel  Tas Waist Bag  Wedges Hitam  \
# Kode Transaksi
# #1                       0           0              0             0
# #10                      0           0              0             1
# #100                     0           0              0             0
# #1000                    0           0              0             0
# #1001                    0           1              0             1
# ...                    ...         ...            ...           ...
# #995                     0           1              0             1
# #996                     0           1              0             0
# #997                     0           0              0             0
# #998                     0           1              0             0
# #999                     1           0              0             0
#
# Nama Barang     Woman Ripped Jeans
# Kode Transaksi
# #1                                0
# #10                               0
# #100                              0
# #1000                             0
# #1001                             0
# ...                             ...
# #995                              0
# #996                              0
# #997                              0
# #998                              0
# #999                              0
#
# [3450 rows x 69 columns]

# %%
from mlxtend.frequent_patterns import apriori
# Menerapkan algoritma apriori parameter untuk menuntukan nilai minimum sari Support
frequent_patterns = apriori(basket_encode,min_support=0.04,use_colnames=True)
frequent_patterns
# Out:
#       support                                           itemsets
# 0    0.118841                                (Atasan Kaos Putih)
# 1    0.380290                                (Baju Batik Wanita)
# 2    0.121159                 (Baju Kaos Anak - Karakter Kartun)
# 3    0.115942                     (Baju Kaos Anak - Superheroes)
# 4    0.089275                               (Baju Kaos Olahraga)
# ..        ...                                                ...
# 744  0.049855  (Sepatu Sekolah Hitam W, Sepatu Sandal Anak, S...
# 745  0.047826  (Serum Vitamin, Tali Pinggang Gesper Pria, Sep...
# 746  0.045797  (Sepatu Sandal Anak, Baju Batik Wanita, Koper ...
# 747  0.042609  (Sepatu Sandal Anak, Baju Kaos Anak - Superher...
# 748  0.047536  (Sepatu Sekolah Hitam W, Sepatu Sandal Anak, B...
#
# [749 rows x 2 columns]

# %%
from mlxtend.frequent_patterns import association_rules

#menerapkan aturan untuk mencari asosiasi antar produk gunakan dataset yang telah diterapkan apriori diurutkan berdasarkan metrik yang digunakan
rules = association_rules(frequent_patterns, metric='lift', min_threshold=1).sort_values('lift', ascending=False).reset_index(drop=True)
rules
# Out:
#                                   antecedents  \
# 0     (Baju Renang Pria Dewasa, Gembok Koper)
# 1               (Atasan Kaos Putih, Tank Top)
# 2           (Atasan Kaos Putih, Gembok Koper)
# 3         (Baju Renang Pria Dewasa, Tank Top)
# 4           (Atasan Kaos Putih, Gembok Koper)
# ...                                       ...
# 2561                   (Celana Jogger Casual)
# 2562            (Shampo Biasa, Serum Vitamin)
# 2563              (Baju Renang Wanita Dewasa)
# 2564           (Tas Waist Bag, Serum Vitamin)
# 2565                      (Baju Kemeja Putih)
#
#                                            consequents  antecedent support  \
# 0                        (Atasan Kaos Putih, Tank Top)            0.046087
# 1              (Baju Renang Pria Dewasa, Gembok Koper)            0.053913
# 2                  (Baju Renang Pria Dewasa, Tank Top)            0.048986
# 3                    (Atasan Kaos Putih, Gembok Koper)            0.051884
# 4              (Baju Renang Pria Dewasa, Wedges Hitam)            0.048986
# ...                                                ...                 ...
# 2561  (Serum Vitamin, Baju Kemeja Putih, Shampo Biasa)            0.329275
# 2562                       (Baju Renang Wanita Dewasa)            0.316232
# 2563                     (Shampo Biasa, Serum Vitamin)            0.142899
# 2564                               (Baju Kemeja Putih)            0.129855
# 2565                    (Tas Waist Bag, Serum Vitamin)            0.363768
#
#       consequent support   support  confidence       lift  leverage  \
# 0               0.053913  0.041159    0.893082  16.565226  0.038675
# 1               0.046087  0.041159    0.763441  16.565226  0.038675
# 2               0.051884  0.041159    0.840237  16.194506  0.038618
# 3               0.048986  0.041159    0.793296  16.194506  0.038618
# 4               0.052754  0.040580    0.828402  15.703232  0.037996
# ...                  ...       ...         ...        ...       ...
# 2561            0.132754  0.043768    0.132923   1.001272  0.000056
# 2562            0.142899  0.045217    0.142988   1.000627  0.000028
# 2563            0.316232  0.045217    0.316430   1.000627  0.000028
# 2564            0.363768  0.047246    0.363839   1.000196  0.000009
# 2565            0.129855  0.047246    0.129880   1.000196  0.000009
#
#       conviction  zhangs_metric
# 0       8.848696       0.985030
# 1       4.032451       0.993178
# 2       5.934503       0.986579
# 3       4.600854       0.989595
# 4       5.520160       0.984547
# ...          ...            ...
# 2561    1.000195       0.001895
# 2562    1.000104       0.000916
# 2563    1.000290       0.000731
# 2564    1.000112       0.000225
# 2565    1.000029       0.000307
#
# [2566 rows x 10 columns]
